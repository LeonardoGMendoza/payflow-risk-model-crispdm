# %% [markdown]
# # 📈 Estatística Descritiva - PayFlow\n\nAnálise estatística descritiva dos dados de crédito.

# %%
import pandas as pd\nimport numpy as np\n\ndf = pd.read_csv('../../data/desafio_payflow.csv')\ndf.describe()
